# %%
import pandas as pd
import numpy as np

# %%
top_100_classified_gene = list(pd.read_csv("welch_t_test_results_to_d2.csv", index_col=0).head(100).index)
top_1000_classified_gene = list(pd.read_csv("welch_t_test_results_to_d2.csv", index_col=0).head(1000).index)

# %%
top_1000_classified_gene
# Out:
# ['C17orf77',
#  'DBNDD1',
#  'ACTRT3',
#  'LINC01186',
#  'RASSF2',
#  'ANLN',
#  'EGR3',
#  'PLEKHH2',
#  'RABL2A///RABL2B',
#  'FRAS1',
#  'ABRA',
#  'FLJ32255',
#  'UGGT1',
#  'FRMPD3',
#  'SIDT1',
#  'LBH',
#  'ITPRIPL1',
#  'CD86',
#  'ANKS3',
#  'TDRD3',
#  'DUSP16',
#  'TLR7',
#  'PGLYRP1',
#  'LOC101929796///LOC100996763///LOC100996717///NOTCH2NL///NOTCH2',
#  'RGCC',
#  'DICER1-AS1',
#  'EDNRB-AS1',
#  'CASQ1',
#  'CXorf51B///CXorf51A',
#  'NFKBIE',
#  'GADD45A',
#  'ITGA9',
#  'LINC00174',
#  'SEPT3',
#  'LOC101930583///GOLGA8B///GOLGA8A',
#  'COL18A1',
#  'C3orf14',
#  'RAB27B',
#  'LOC101060363///PPIA',
#  'SOHLH2',
#  'ZNF568',
#  'NEDD9',
#  'ATF3',
#  'ZMIZ1-AS1',
#  'LMNTD1',
#  'LYZ',
#  'RAB33A',
#  'CSF2RB',
#  'LOC441454',
#  'RAB39B',
#  'ZBTB40',
#  'SCGB1D2',
#  'CMTM7',
#  'SLIT2',
#  'SLC35F3',
#  'ABHD6',
#  'LYRM7',
#  'CDK11A///CDK11B',
#  'GPR78///CPZ',
#  'WDR83',
#  'PDE4B',
#  'UBXN1',
#  'MBD3',
#  'DPP7',
#  'SRD5A3-AS1',
#  'LOC105375531',
# ...

# %%
df_gene_expression = pd.read_csv("../BE700_human_expression.(1) (1) (1).csv", sep=',', index_col=0)
df_gene_expression = df_gene_expression.loc[top_1000_classified_gene].T

# %%
df_pheno = pd.read_csv("../human_pheno_postprocessed.csv", sep=',', index_col=0)
df_gene_expression['diabete'] = df_pheno['diabete_2']
df_gene_expression

df_gene_expression.to_csv("../WEKA_DATA/")
# Out:
#            C17orf77     DBNDD1    ACTRT3  LINC01186     RASSF2      ANLN  \
# GSM624925  4.035624   9.150255  6.556123  10.072669  10.007027  6.342970
# GSM624926  4.472488   8.211888  5.646739   9.525521   9.414685  8.185004
# GSM624927  8.020147   7.452035  7.187847  10.053383   9.772315  7.255027
# GSM624928  5.904484  10.405461  6.456149  10.145677   9.339627  7.552110
# GSM624929  5.364572   8.071462  7.099085  10.097505  10.097505  5.950188
# GSM624930  5.765535   9.053383  6.091700  10.314583  10.021119  8.838790
# GSM624931  5.963474   9.747689  6.149747   9.632632   9.699399  6.236472
# GSM624932  8.356672   8.308339  8.197217   9.654278   9.191800  6.263201
# GSM624933  5.965784   9.601771  7.155830   9.849405  10.296228  6.781360
# GSM624934  6.427941  10.268542  6.232661   9.574783  10.126963  8.046182
# GSM624935  7.804776  10.565578  5.683696  10.061641   9.710979  7.888374
# GSM624936  7.400879   9.997321  6.811214   9.922882   9.931476  6.688010
# ...
